# %% [markdown]
# # Task- 01
#
# ### Importing necessary libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Reading CSV file

# %%
df = pd.read_csv("worldpopulationdata.csv")

# %% [markdown]
# ### Checking top 10 rows data from CSV file

# %%
df.head(10)
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
# 5                      Albania          ALB  Population, total    SP.POP.TOTL
# 6                      Andorra          AND  Population, total    SP.POP.TOTL
# 7                   Arab World          ARB  Population, total    SP.POP.TOTL
# 8         United Arab Emirates          ARE  Population, total    SP.POP.TOTL
# 9                    Argentina          ARG  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# ...

# %% [markdown]
# ### Checking 10 data from the bottom

# %%
df.tail(10)
# Out:
#                Country Name Country Code  \
# 1313  Virgin Islands (U.S.)          VIR
# 1314               Viet Nam          VNM
# 1315                Vanuatu          VUT
# 1316                  World          WLD
# 1317                  Samoa          WSM
# 1318                 Kosovo          XKX
# 1319            Yemen, Rep.          YEM
# 1320           South Africa          ZAF
# 1321                 Zambia          ZMB
# 1322               Zimbabwe          ZWE
#
#                                 Indicator Name     Indicator Code       1960  \
# 1313  Population, male (% of total population)  SP.POP.TOTL.MA.ZS  49.241438
# 1314  Population, male (% of total population)  SP.POP.TOTL.MA.ZS  49.355210
# 1315  Population, male (% of total population)  SP.POP.TOTL.MA.ZS  53.913489
# 1316  Population, male (% of total population)  SP.POP.TOTL.MA.ZS  49.898571
# 1317  Population, male (% of total population)  SP.POP.TOTL.MA.ZS  51.237877
# ...

# %% [markdown]
# ### Checking the total no of columns in the CSV file

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', '2024'],
#       dtype='object')

# %% [markdown]
# ### Some Information about the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1323 entries, 0 to 1322
# Data columns (total 69 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    1323 non-null   object
#  1   Country Code    1323 non-null   object
#  2   Indicator Name  1323 non-null   object
#  3   Indicator Code  1323 non-null   object
#  4   1960            1323 non-null   float64
#  5   1961            1323 non-null   float64
#  6   1962            1323 non-null   float64
#  7   1963            1323 non-null   float64
#  8   1964            1323 non-null   float64
#  9   1965            1323 non-null   float64
#  10  1966            1323 non-null   float64
#  11  1967            1323 non-null   float64
#  12  1968            1323 non-null   float64
#  13  1969            1323 non-null   float64
#  14  1970            1323 non-null   float64
#  15  1971            1323 non-null   float64
#  16  1972            1323 non-null   float64
# ...

# %%
df.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  1.323000e+03  1.323000e+03  1.323000e+03  1.323000e+03  1.323000e+03
# mean   4.605769e+07  4.669814e+07  4.756055e+07  4.862626e+07  4.970152e+07
# std    2.022366e+08  2.047567e+08  2.084694e+08  2.132727e+08  2.181030e+08
# min    3.654514e+01  3.618269e+01  3.649327e+01  3.616714e+01  3.580017e+01
# 25%    5.044541e+01  5.044969e+01  5.045879e+01  5.044907e+01  5.044688e+01
# 50%    8.367100e+04  8.543400e+04  8.726100e+04  8.973700e+04  9.282300e+04
# 75%    3.861132e+06  3.962543e+06  4.033526e+06  4.148054e+06  4.259602e+06
# max    3.021513e+09  3.062768e+09  3.117372e+09  3.184063e+09  3.251253e+09
#
#                1965          1966          1967          1968          1969  \
# count  1.323000e+03  1.323000e+03  1.323000e+03  1.323000e+03  1.323000e+03
# mean   5.078945e+07  5.192514e+07  5.306390e+07  5.423254e+07  5.544038e+07
# ...

# %% [markdown]
# ### Checking the duplicate data values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Checking the missing data values

# %%
df.isna().sum()
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 1960              0
#                  ..
# 2020              0
# 2021              0
# 2022              0
# 2023              0
# 2024              0
# Length: 69, dtype: int64

# %% [markdown]
# ### Checking the unique values for the columns

# %%
print(df['Country Name'].unique())
print("\n Total no of unique countries:", df['Country Name'].nunique())
# Out:
# ['Aruba' 'Africa Eastern and Southern' 'Afghanistan'
#  'Africa Western and Central' 'Angola' 'Albania' 'Andorra' 'Arab World'
#  'United Arab Emirates' 'Argentina' 'Armenia' 'American Samoa'
#  'Antigua and Barbuda' 'Australia' 'Austria' 'Azerbaijan' 'Burundi'
#  'Belgium' 'Benin' 'Burkina Faso' 'Bangladesh' 'Bulgaria' 'Bahrain'
#  'Bahamas, The' 'Bosnia and Herzegovina' 'Belarus' 'Belize' 'Bermuda'
#  'Bolivia' 'Brazil' 'Barbados' 'Brunei Darussalam' 'Bhutan' 'Botswana'
#  'Central African Republic' 'Canada' 'Central Europe and the Baltics'
#  'Switzerland' 'Channel Islands' 'Chile' 'China' "Cote d'Ivoire"
#  'Cameroon' 'Congo, Dem. Rep.' 'Congo, Rep.' 'Colombia' 'Comoros'
#  'Cabo Verde' 'Costa Rica' 'Caribbean small states' 'Cuba' 'Curacao'
#  'Cayman Islands' 'Cyprus' 'Czechia' 'Germany' 'Djibouti' 'Dominica'
#  'Denmark' 'Dominican Republic' 'Algeria'
#  'East Asia & Pacific (excluding high income)'
#  'Early-demographic dividend' 'East Asia & Pacific'
# ...

# %%
print(df['Country Code'].unique())
print("\n Total no of unique country codes:", df['Country Code'].nunique())
# Out:
# ['ABW' 'AFE' 'AFG' 'AFW' 'AGO' 'ALB' 'AND' 'ARB' 'ARE' 'ARG' 'ARM' 'ASM'
#  'ATG' 'AUS' 'AUT' 'AZE' 'BDI' 'BEL' 'BEN' 'BFA' 'BGD' 'BGR' 'BHR' 'BHS'
#  'BIH' 'BLR' 'BLZ' 'BMU' 'BOL' 'BRA' 'BRB' 'BRN' 'BTN' 'BWA' 'CAF' 'CAN'
#  'CEB' 'CHE' 'CHI' 'CHL' 'CHN' 'CIV' 'CMR' 'COD' 'COG' 'COL' 'COM' 'CPV'
#  'CRI' 'CSS' 'CUB' 'CUW' 'CYM' 'CYP' 'CZE' 'DEU' 'DJI' 'DMA' 'DNK' 'DOM'
#  'DZA' 'EAP' 'EAR' 'EAS' 'ECA' 'ECS' 'ECU' 'EGY' 'EMU' 'ERI' 'ESP' 'EST'
#  'ETH' 'EUU' 'FCS' 'FIN' 'FJI' 'FRA' 'FRO' 'FSM' 'GAB' 'GBR' 'GEO' 'GHA'
#  'GIB' 'GIN' 'GMB' 'GNB' 'GNQ' 'GRC' 'GRD' 'GRL' 'GTM' 'GUM' 'GUY' 'HIC'
#  'HKG' 'HND' 'HPC' 'HRV' 'HTI' 'HUN' 'IBD' 'IBT' 'IDA' 'IDB' 'IDN' 'IDX'
#  'IMN' 'IND' 'IRL' 'IRN' 'IRQ' 'ISL' 'ISR' 'ITA' 'JAM' 'JOR' 'JPN' 'KAZ'
#  'KEN' 'KGZ' 'KHM' 'KIR' 'KNA' 'KOR' 'KWT' 'LAC' 'LAO' 'LBN' 'LBR' 'LBY'
#  'LCA' 'LCN' 'LDC' 'LIC' 'LIE' 'LKA' 'LMC' 'LMY' 'LSO' 'LTE' 'LTU' 'LUX'
#  'LVA' 'MAC' 'MAF' 'MAR' 'MCO' 'MDA' 'MDG' 'MDV' 'MEA' 'MEX' 'MHL' 'MIC'
# ...

# %% [markdown]
# ### Dropping unnecessary columns

# %%
df.drop(['Indicator Name','Country Name'], axis=1, inplace=True)

# %% [markdown]
# ### Extraction  of the top 10 countries with respect to total population

# %%
# Filter data for total population
total_population_data=df[df['Indicator Code']=='SP.POP.TOTL']

# Sort data based on the total population
total_population_sorted = total_population_data.sort_values(by="2024",ascending = False)

# Get the top ten countries with the highest total population for 2024
total_top_ten_countries = total_population_sorted.head(10)

print("Top ten countries of total population \n")
print(total_top_ten_countries[['Country Code']])
# Out:
# Top ten countries of total population
#
#     Country Code
# 258          WLD
# 103          IBT
# 139          LMY
# 155          MIC
# 102          IBD
# 62           EAR
# 138          LMC
# 248          UMC
# 63           EAS
# 141          LTE

# %% [markdown]
# ### Bar plot of this data

# %% [markdown]
# #### Top ten countries of total population in the year 2020 and 2024

# %%
# Create a bar plot
plt.figure(figsize=(15,6))
plt.subplot(2,2,1)
sns.barplot(x="2024", y = "Country Code",hue="Country Code",data = total_top_ten_countries, palette = "coolwarm")
plt.title("Top ten countries of total population(2024)", fontsize=10)
plt.xlabel("Total Population",fontsize=10)
plt.ylabel("Countries", fontsize=10)
plt.show()


# Create a bar plot
plt.figure(figsize=(15,6))
plt.subplot(2,2,2)
sns.barplot(x="2020", y = "Country Code",hue="Country Code",data = total_top_ten_countries, palette = "coolwarm")
plt.title("Top ten countries of total population(2020)", fontsize=10)
plt.xlabel("Total Population",fontsize=10)
plt.ylabel("Countries", fontsize=10)
plt.show()

# %% [markdown]
# ### Extraction of the top 10 countries with respect to total population from the bottom

# %%
# Sort data based on the total population
total_population_sorted_1 = total_population_data.sort_values(by="2024",ascending = True)

# Get the top ten countries with the highest total population for 2024
total_bottom_ten_countries = total_population_sorted_1.head(10)

print("Bottom ten countries of total population \n")
print(total_bottom_ten_countries[['Country Code']])
# Out:
# Bottom ten countries of total population
#
#     Country Code
# 244          TUV
# 178          NRU
# 187          PLW
# 146          MAF
# 211          SMR
# 154          MHL
# 148          MCO
# 84           GIB
# 254          VGB
# 136          LIE

# %% [markdown]
# ### Bar plot of this data
# #### Bottom 10 countries of total population in the year 2020 and 2024

# %%
# Create a bar plot
plt.figure(figsize=(15,6))
plt.subplot(2,2,1)
sns.barplot(x="2024", y = "Country Code",hue="Country Code",data = total_bottom_ten_countries, palette = "coolwarm")
plt.title("Bottom ten countries of total population(2024)", fontsize=10)
plt.xlabel("Total Population",fontsize=10)
plt.ylabel("Countries", fontsize=10)
plt.show()


# Create a bar plot
plt.figure(figsize=(15,6))
plt.subplot(2,2,2)
sns.barplot(x="2020", y = "Country Code",hue="Country Code",data = total_bottom_ten_countries, palette = "coolwarm")
plt.title("Bottom ten countries of total population(2020)", fontsize=10)
plt.xlabel("Total Population",fontsize=10)
plt.ylabel("Countries", fontsize=10)
plt.show()

# %% [markdown]
# ### Extraction of up to 10 countries with the highest male population

# %%
# Filter data for the male population 
male_population_data = df[df['Indicator Code']=='SP.POP.TOTL.MA.IN']

# Sort data based on the male population for 2024
male_population_sorted = male_population_data.sort_values(by = "2024", ascending=False)

# Get the top 10 countries with the highest male population for 2024
male_top_ten_countries = male_population_sorted.head(10)

print("Top 10 countries of male population")
print(male_top_ten_countries[['Country Code']])
# Out:
# Top 10 countries of male population
#     Country Code
# 786          WLD
# 632          IBT
# 668          LMY
# 684          MIC
# 631          IBD
# 591          EAR
# 667          LMC
# 776          UMC
# 592          EAS
# 670          LTE

# %% [markdown]
# ### Extraction of up to 10 countries with the highest male population

# %%
# Filter data for the male population 
female_population_data = df[df['Indicator Code']=='SP.POP.TOTL.FE.IN']

# Sort data based on the male population for 2024
female_population_sorted = female_population_data.sort_values(by = "2024", ascending=False)

# Get the top 10 countries with the highest male population for 2024
female_top_ten_countries = female_population_sorted.head(10)

print("Top 10 countries of female population")
print(female_top_ten_countries[['Country Code']])
# Out:
# Top 10 countries of female population
#     Country Code
# 522          WLD
# 368          IBT
# 404          LMY
# 420          MIC
# 367          IBD
# 327          EAR
# 403          LMC
# 512          UMC
# 328          EAS
# 406          LTE

# %% [markdown]
# ### Top 10 countries with the highest male and female populations in 2024

# %%
# Create a bar plot
plt.figure(figsize=(15,6))
plt.subplot(2,2,1)
sns.barplot(x="2024", y = "Country Code",hue="Country Code",data = male_top_ten_countries, palette = "viridis")
plt.title("Top ten countries of male population(2024)", fontsize=10)
plt.xlabel("Male  Population",fontsize=10)
plt.ylabel("Countries", fontsize=10)
plt.show()


# Create a bar plot
plt.figure(figsize=(15,6))
plt.subplot(2,2,2)
sns.barplot(x="2024", y = "Country Code",hue="Country Code",data = female_top_ten_countries, palette = "coolwarm")
plt.title("Top ten countries of female population(2024)", fontsize=10)
plt.xlabel("Female Population",fontsize=10)
plt.ylabel("Countries", fontsize=10)
plt.show()

# %% [markdown]
# ### Stacked Bar plot
#
# #### Top 10 countries with male and female population

# %%
# Merge male and female population data on 'Country Code'
merge_data= pd.merge(male_population_data,female_population_data, on="Country Code", suffixes=("_male","_female"))

# %%
# Merged data
# Calculate the total population for each country (Male+Female)

merge_data["Total population"] = merge_data["2024_male"]+merge_data["2024_female"]

# %%
merge_data.head()
# Out:
#   Country Code Indicator Code_male   1960_male   1961_male   1962_male  \
# 0          ABW   SP.POP.TOTL.MA.IN     26995.0     27326.0     27692.0
# 1          AFE   SP.POP.TOTL.MA.IN  64411379.0  66120634.0  67916448.0
# 2          AFG   SP.POP.TOTL.MA.IN   4690245.0   4775684.0   4867111.0
# 3          AFW   SP.POP.TOTL.MA.IN  48455513.0  49456062.0  50496568.0
# 4          AGO   SP.POP.TOTL.MA.IN   2649099.0   2690647.0   2721244.0
#
#     1963_male   1964_male   1965_male   1966_male   1967_male  ...  \
# 0     28027.0     28334.0     28614.0     28855.0     28999.0  ...
# 1  69778027.0  71729676.0  73764113.0  75854712.0  78035195.0  ...
# 2   4963703.0   5065414.0   5173290.0   5285657.0   5402774.0  ...
# 3  51587717.0  52711199.0  53877859.0  55091272.0  56338265.0  ...
# 4   2752564.0   2784880.0   2818210.0   2852358.0   2887186.0  ...
#
#    2016_female  2017_female  2018_female  2019_female  2020_female  \
# ...

# %%
# sort data based on total population in descending order
sorted_data = merge_data.sort_values(by="Total population", ascending=False)

# %% [markdown]
# ### Select the top 10 countries with the highest total population

# %%
top_10_countries = sorted_data.head(10)

# %%
# Create the stacked bar plot
plt.figure(figsize=(12,6))
sns.barplot(x="Country Code", y="2024_female",data=top_10_countries, color="red", label="female Population")
sns.barplot(x="Country Code", y="2024_male",data=top_10_countries,bottom=top_10_countries["2024_female"], color="blue", label="male Population")
plt.xlabel("country")
plt.ylabel("Population")
plt.legend()
plt.xticks(rotation=45,ha="right")
plt.show()

# %% [markdown]
# ### Bottom 10 countries with male and female population(2024)

# %%
# select the bottom 10 countries with the highest total population
bottom_10_countries = sorted_data.tail(10)

# %%
# Create the stacked bar plot
plt.figure(figsize=(12,6))
sns.barplot(x="Country Code", y="2024_female",data=top_10_countries, color="red", label="female Population")
sns.barplot(x="Country Code", y="2024_male",data=top_10_countries,bottom=top_10_countries["2024_female"], color="blue", label="male Population")
plt.title("Distribution of Male Population (Top 10 Countries - 2024)")
plt.xlabel("country")
plt.ylabel("Population")
plt.legend()
plt.xticks(rotation=45,ha="right")
plt.show()

# %%
plt.figure(figsize=(10,6))

# Histogram of male population
sns.histplot(top_10_countries["2024_male"], bins=10, kde=True, color="blue", label="Male Population", alpha=0.6)

plt.xlabel("Population")
plt.ylabel("Frequency")
plt.title("Distribution of Male Population (Top 10 Countries - 2024)")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,6))

# Male population
sns.histplot(top_10_countries["2024_male"], 
             bins=10, kde=False, color="blue", 
             label="Male Population", alpha=0.6, edgecolor="black")

# Female population
sns.histplot(top_10_countries["2024_female"], 
             bins=10, kde=False, color="red", 
             label="Female Population", alpha=0.6, edgecolor="black")

plt.xlabel("Population", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.title("Distribution of Male & Female Population (Top 10 Countries - 2024)", fontsize=14)
plt.legend()
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()
